# %%
from poibin import PoiBin
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 from poibin import PoiBin
#       2 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'poibin'

# %%
p = [0.1,0.3,0.4,0.9]

#p[1]=0.5
#p[2]=0.1
#p[3]=0.0
#p[4]=0.9
#p[5]=1.0
#p[6]=1.0
#p[7]=0.9
#p[8]=0.1
#p[9]=0.0

pb = PoiBin(p)
prob = pb.pmf(range(4))
print(prob)
fig=plt.figure()
x= range(4)
plt.bar(x,prob)
# Out:
# [0.0378 0.3858 0.4258 0.1398]
# <BarContainer object of 4 artists>
